# %%
print("OK")
# Out:
# OK

# %%
import pandas as pd
from evidently import Report
from evidently.presets import DataDriftPreset

# %% [markdown]
# ## Load out Boston data

# %%
data_url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
boston_frame = pd.read_csv(data_url)

# %%
boston_frame.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# # Data Drift Dashboard

# %%
boston_frame.shape
# Out:
# (506, 14)

# %%
boston_frame[:200]  #train/ reference data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 195  0.01381  80.0   0.46     0  0.422  7.875  32.0  5.6484    4  255
# 196  0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 197  0.04666  80.0   1.52     0  0.404  7.107  36.6  7.3090    2  329
# 198  0.03768  80.0   1.52     0  0.404  7.274  38.3  7.3090    2  329
# 199  0.03150  95.0   1.47     0  0.403  6.975  15.3  7.6534    3  402
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 195     14.4  394.23   2.97  50.0
# 196     12.6  396.90   4.08  33.3
# 197     12.6  354.31   8.61  30.3
# 198     12.6  392.20   6.62  34.6
# 199     17.0  396.90   4.56  34.9
#
# [200 rows x 14 columns]

# %%
boston_frame[200:] #test data
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 200  0.01778  95.0   1.47     0  0.4030  7.135  13.9  7.6534    3  402
# 201  0.03445  82.5   2.03     0  0.4150  6.162  38.4  6.2700    2  348
# 202  0.02177  82.5   2.03     0  0.4150  7.610  15.7  6.2700    2  348
# 203  0.03510  95.0   2.68     0  0.4161  7.853  33.2  5.1180    4  224
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# ..       ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.5730  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.5730  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.5730  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.5730  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.5730  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 200     17.0  384.30   4.45  32.9
# 201     14.7  393.77   7.43  24.1
# 202     14.7  395.38   3.11  42.3
# 203     14.7  392.78   3.81  48.5
# 204     14.7  390.55   2.88  50.0
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [306 rows x 14 columns]

# %%
# Modern equivalent 
boston_data_drift_dashboard = Report(metrics=[
    DataDriftPreset()
])

# %%
boston_data_drift_dashboard = boston_data_drift_dashboard.run(
    reference_data=boston_frame[:200], 
    current_data=boston_frame[200:]
)
# Out:
# c:\Users\zohai\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_stats_py.py:7277: RuntimeWarning:
#
# divide by zero encountered in divide
#
# c:\Users\zohai\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_stats_py.py:7277: RuntimeWarning:
#
# divide by zero encountered in divide
#
# c:\Users\zohai\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_stats_py.py:7277: RuntimeWarning:
#
# divide by zero encountered in divide

# %%
boston_data_drift_dashboard.save_html("boston_drift_report.html")

# %%
drift_json = boston_data_drift_dashboard.json()

# %%
drift_json
# Out:
# '{"metrics": [{"id": "15e89f895b482f9b84ba7274ed18a106", "metric_name": "DriftedColumnsCount(drift_share=0.5)", "config": {"type": "evidently:metric_v2:DriftedColumnsCount", "drift_share": 0.5}, "value": {"count": 11.0, "share": 0.7857142857142857}}, {"id": "3faab42b9bd0fcf87c1173996570bcdd", "metric_name": "ValueDrift(column=crim,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "crim", "method": "K-S p_value", "threshold": 0.05}, "value": 4.762113906763963e-19}, {"id": "559bc26ff939091e3bb395651db789c5", "metric_name": "ValueDrift(column=zn,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "zn", "method": "K-S p_value", "threshold": 0.05}, "value": 0.3296581129241252}, {"id": "61ac8011b10b8ba535d032549a35ca73", "metric_name": "ValueDrift(column=indus,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "indus", "method": "K-S p_value", "threshold": 0.05}, "value": 8.314376567541265e-07}, {"id": "9621ec735e30e464f461f7cdb0c57f7b", "metric_name": "ValueDrift(column=nox,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "nox", "method": "K-S p_value", "threshold": 0.05}, "value": 1.9346847664313096e-08}, {"id": "82862d3e3071fdd115a931ce87df7ad3", "metric_name": "ValueDrift(column=rm,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "rm", "method": "K-S p_value", "threshold": 0.05}, "value": 0.04004517224038903}, {"id": "1cf7e5c2a8eb2a62a2667e70ee06d259", "metric_name": "ValueDrift(column=age,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "age", "method": "K-S p_value", "threshold": 0.05}, "value": 0.6415070107915689}, {"id": "f6815b973692be969967f877951d7d23", "metric_name": "ValueDrift(column=dis,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "dis", "method": "K-S p_value", "threshold": 0.05}, "value": 0.01927677503139847}, {"id": "caff7f12e87cc414e55f38b562fb1592", "metric_name": "ValueDrift(column=tax,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "tax", "method": "K-S p_value", "threshold": 0.05}, "value": 2.1700381740167622e-22}, {"id": "2a2c646c572ede521b8599b7daf37feb", "metric_name": "ValueDrift(column=ptratio,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "ptratio", "method": "K-S p_value", "threshold": 0.05}, "value": 2.2005715930927168e-07}, {"id": "45e62e7e03916974f7a2a30fa115e44e", "metric_name": "ValueDrift(column=b,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "b", "method": "K-S p_value", "threshold": 0.05}, "value": 0.08648769162441368}, {"id": "13508f6c417ceac682b692e172a29779", "metric_name": "ValueDrift(column=lstat,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "lstat", "method": "K-S p_value", "threshold": 0.05}, "value": 0.014708979302925057}, {"id": "ea39a1e4467591045485c27ac534fc06", "metric_name": "ValueDrift(column=medv,method=K-S p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "medv", "method": "K-S p_value", "threshold": 0.05}, "value": 0.0022656918322324525}, {"id": "fb78503f0a1ec02a497539cad3509f62", "metric_name": "ValueDrift(column=chas,method=Z-test p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "chas", "method": "Z-test p_value", "threshold": 0.05}, "value": 0.014327301622407473}, {"id": "4410a0b247eebabea3a40dd7420c0fd9", "metric_name": "ValueDrift(column=rad,method=chi-square p_value,threshold=0.05)", "config": {"type": "evidently:metric_v2:ValueDrift", "column": "rad", "method": "chi-square p_value", "threshold": 0.05}, "value": 0.0}], "tests": []}'
